# %%
import pandas as pd
import os

# %%
df_gender = pd.read_csv("data/reddit_comments_gender_female_processed_phrase_annotated.csv")
df_orientation = pd.read_csv("data/reddit_comments_orientation_lgbtq_processed_phrase_annotated.csv")
df_race = pd.read_csv("data/reddit_comments_race_black_processed_phrase_annotated.csv")
# df_religion1 = pd.read_csv("reddit_comments_religion1_jews_processed_phrase_annotated.csv")
df_religion1 = pd.read_csv(
    "data/reddit_comments_religion1_jews_processed_phrase_annotated.csv",
    encoding="latin1"
)
df_religion2 = pd.read_csv("data/reddit_comments_religion2_muslims_processed_phrase_annotated.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_gender = pd.read_csv("reddit_comments_gender_female_processed_phrase_annotated.csv")
#       2 df_orientation = pd.read_csv("reddit_comments_orientation_lgbtq_processed_phrase_annotated.csv")
#       3 df_race = pd.read_csv("reddit_comments_race_black_processed_phrase_annotated.csv")
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df_gender["category"] = "gender_female"
df_race["category"] = "race_black"
df_religion1["category"] = "religion_jews"
df_religion2["category"] = "religion_muslim"
df_orientation["category"] = "orientation_lgbt"

# %%
combined_df = pd.concat(
    [df_gender, df_race, df_religion1, df_religion2, df_orientation],
    ignore_index=True
)

# %%
df_religion1.head()
df_religion2.head()
combined_df.head()
# Out:
#    attribute_in_window                                            comment  \
# 0                 True  im sorry this is happening for you. at least y...
# 1                 True       their mothers are in on the joke art project
# 2                 True  i feel like this is some deep artistic dance t...
# 3                 True  or biology. over protective and smothering mot...
# 4                 True  writing poetry to a girl is the fastest way to...
#
#                                               phrase bias_sent  bias_phrase  \
# 0  least you know whats happening now. narcissist...         0          0.0
# 1       their mothers are in on the joke art project         1          1.0
# 2  artistic dance thats trying to highlight how m...         0          0.0
# 3  or biology. over protective and smothering mot...         0          0.0
# 4  writing poetry to a girl is the fastest way to...         0          0.0
#
#    Unnamed: 5       category   id
# ...

# %%
cleaned_df = df[['data_source', 'comment', 'bias_sent']]
na_counts = cleaned_df.isna().sum()

# %%
os.makedirs("data", exist_ok=True)
cleaned_df.to_csv("data/cleaned_data.csv", index=False)
